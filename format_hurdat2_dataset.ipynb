# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/hurdat2.csv')

# %%
df.head(5)
# Out:
#    storm_id storm_name  num_of_obs      date  time record_identifier  \
# 0  AL041851    UNNAMED          49  18510823  1200               NaN
# 1  AL041851    UNNAMED          49  18510823  1800               NaN
# 2  AL041851    UNNAMED          49  18510823  2100                 L
# 3  AL041851    UNNAMED          49  18510824     0               NaN
# 4  AL011852    UNNAMED          45  18520826  1800               NaN
#
#   status_of_system  latitude  longitude  maximum_sustained_wind_knots  ...  \
# 0               HU      28.5      -86.6                           100  ...
# 1               HU      29.6      -86.1                           100  ...
# 2               HU      30.1      -85.7                           100  ...
# 3               HU      30.7      -85.1                            90  ...
# 4               HU      31.2      -88.1                            70  ...
#
#    34_kt_nw_nm  50_kt_ne_nm  50_kt_se_nm  50_kt_sw_nm  50_kt_nw_nm  \
# 0         -999         -999         -999         -999         -999
# 1         -999         -999         -999         -999         -999
# 2         -999         -999         -999         -999         -999
# 3         -999         -999         -999         -999         -999
# 4         -999         -999         -999         -999         -999
#
#    64_kt_ne_nm  64_kt_se_nm  64_kt_sw_nm  64_kt_nw_nm  radius_of_max_wind_nm
# 0         -999         -999         -999         -999                   -999
# 1         -999         -999         -999         -999                   -999
# 2         -999         -999         -999         -999                   -999
# 3         -999         -999         -999         -999                   -999
# 4         -999         -999         -999         -999                   -999
#
# [5 rows x 24 columns]

# %%
df["date"] = df["date"].astype(str)
df["time"] = df["time"].astype(str).str.zfill(4)

# %%
df["formatted_date"] = pd.to_datetime(df["date"], format="%Y%m%d").dt.strftime("%Y-%m-%d")

# %%
df["formatted_time"] = df["time"].str[:2] + ":" + df["time"].str[2:] + ":00"

# %%
df["datetime"] = df["formatted_date"] + " " + df["formatted_time"]

# %%
df.head(5)
# Out:
#    storm_id storm_name  num_of_obs      date  time record_identifier  \
# 0  AL041851    UNNAMED          49  18510823  1200               NaN
# 1  AL041851    UNNAMED          49  18510823  1800               NaN
# 2  AL041851    UNNAMED          49  18510823  2100                 L
# 3  AL041851    UNNAMED          49  18510824  0000               NaN
# 4  AL011852    UNNAMED          45  18520826  1800               NaN
#
#   status_of_system  latitude  longitude  maximum_sustained_wind_knots  ...  \
# 0               HU      28.5      -86.6                           100  ...
# 1               HU      29.6      -86.1                           100  ...
# 2               HU      30.1      -85.7                           100  ...
# 3               HU      30.7      -85.1                            90  ...
# 4               HU      31.2      -88.1                            70  ...
#
#    50_kt_sw_nm  50_kt_nw_nm  64_kt_ne_nm  64_kt_se_nm  64_kt_sw_nm  \
# 0         -999         -999         -999         -999         -999
# 1         -999         -999         -999         -999         -999
# 2         -999         -999         -999         -999         -999
# 3         -999         -999         -999         -999         -999
# 4         -999         -999         -999         -999         -999
#
#    64_kt_nw_nm  radius_of_max_wind_nm  formatted_time  formatted_date  \
# 0         -999                   -999        12:00:00      1851-08-23
# 1         -999                   -999        18:00:00      1851-08-23
# 2         -999                   -999        21:00:00      1851-08-23
# 3         -999                   -999        00:00:00      1851-08-24
# 4         -999                   -999        18:00:00      1852-08-26
#
#               datetime
# 0  1851-08-23 12:00:00
# 1  1851-08-23 18:00:00
# 2  1851-08-23 21:00:00
# 3  1851-08-24 00:00:00
# 4  1852-08-26 18:00:00
#
# [5 rows x 27 columns]

# %%
df.drop(columns=["date", "time", "formatted_date", "formatted_time"], inplace=True)

# %%
datetime_col = df.pop("datetime")
df.insert(3, "datetime", datetime_col)

# %%
df.head(5)
# Out:
#    storm_id storm_name  num_of_obs             datetime record_identifier  \
# 0  AL041851    UNNAMED          49  1851-08-23 12:00:00               NaN
# 1  AL041851    UNNAMED          49  1851-08-23 18:00:00               NaN
# 2  AL041851    UNNAMED          49  1851-08-23 21:00:00                 L
# 3  AL041851    UNNAMED          49  1851-08-24 00:00:00               NaN
# 4  AL011852    UNNAMED          45  1852-08-26 18:00:00               NaN
#
#   status_of_system  latitude  longitude  maximum_sustained_wind_knots  \
# 0               HU      28.5      -86.6                           100
# 1               HU      29.6      -86.1                           100
# 2               HU      30.1      -85.7                           100
# 3               HU      30.7      -85.1                            90
# 4               HU      31.2      -88.1                            70
#
#    central_pressure_mb  ...  34_kt_nw_nm  50_kt_ne_nm  50_kt_se_nm  \
# 0                 -999  ...         -999         -999         -999
# 1                 -999  ...         -999         -999         -999
# 2                 -999  ...         -999         -999         -999
# 3                 -999  ...         -999         -999         -999
# 4                 -999  ...         -999         -999         -999
#
#    50_kt_sw_nm  50_kt_nw_nm  64_kt_ne_nm  64_kt_se_nm  64_kt_sw_nm  \
# 0         -999         -999         -999         -999         -999
# 1         -999         -999         -999         -999         -999
# 2         -999         -999         -999         -999         -999
# 3         -999         -999         -999         -999         -999
# 4         -999         -999         -999         -999         -999
#
#    64_kt_nw_nm  radius_of_max_wind_nm
# 0         -999                   -999
# 1         -999                   -999
# 2         -999                   -999
# 3         -999                   -999
# 4         -999                   -999
#
# [5 rows x 23 columns]

# %% [markdown]
# Add category column for each observation | wind speed is in knots

# %%
def  classify_category(wind_speed):
    if wind_speed <= 33:
        return "Tropical Depression"
    elif 34 <= wind_speed <= 63:
        return "Tropical Storm"
    elif 64 <= wind_speed <= 82:
        return 1
    elif 83 <= wind_speed <= 95:
        return 2
    elif 96 <= wind_speed <= 112:
        return 3
    elif 113 <= wind_speed <= 136:
        return 4
    elif wind_speed >= 137:
        return 5
    return "Unknown"

# %% [markdown]
# Apply the function to the dataset

# %%
df["category"] = df["maximum_sustained_wind_knots"].apply(classify_category)
df.head(5)
# Out:
#    storm_id storm_name  num_of_obs             datetime record_identifier  \
# 0  AL041851    UNNAMED          49  1851-08-23 12:00:00               NaN
# 1  AL041851    UNNAMED          49  1851-08-23 18:00:00               NaN
# 2  AL041851    UNNAMED          49  1851-08-23 21:00:00                 L
# 3  AL041851    UNNAMED          49  1851-08-24 00:00:00               NaN
# 4  AL011852    UNNAMED          45  1852-08-26 18:00:00               NaN
#
#   status_of_system  latitude  longitude  maximum_sustained_wind_knots  \
# 0               HU      28.5      -86.6                           100
# 1               HU      29.6      -86.1                           100
# 2               HU      30.1      -85.7                           100
# 3               HU      30.7      -85.1                            90
# 4               HU      31.2      -88.1                            70
#
#    central_pressure_mb  ...  50_kt_ne_nm  50_kt_se_nm  50_kt_sw_nm  \
# 0                 -999  ...         -999         -999         -999
# 1                 -999  ...         -999         -999         -999
# 2                 -999  ...         -999         -999         -999
# 3                 -999  ...         -999         -999         -999
# 4                 -999  ...         -999         -999         -999
#
#    50_kt_nw_nm  64_kt_ne_nm  64_kt_se_nm  64_kt_sw_nm  64_kt_nw_nm  \
# 0         -999         -999         -999         -999         -999
# 1         -999         -999         -999         -999         -999
# 2         -999         -999         -999         -999         -999
# 3         -999         -999         -999         -999         -999
# 4         -999         -999         -999         -999         -999
#
#    radius_of_max_wind_nm  category
# 0                   -999         3
# 1                   -999         3
# 2                   -999         3
# 3                   -999         2
# 4                   -999         1
#
# [5 rows x 24 columns]

# %% [markdown]
# Rearrange the columns

# %%
category_col = df.pop("category")
df.insert(4, "category", category_col)
df.head(5)
# Out:
#    storm_id storm_name  num_of_obs             datetime category  \
# 0  AL041851    UNNAMED          49  1851-08-23 12:00:00        3
# 1  AL041851    UNNAMED          49  1851-08-23 18:00:00        3
# 2  AL041851    UNNAMED          49  1851-08-23 21:00:00        3
# 3  AL041851    UNNAMED          49  1851-08-24 00:00:00        2
# 4  AL011852    UNNAMED          45  1852-08-26 18:00:00        1
#
#   record_identifier status_of_system  latitude  longitude  \
# 0               NaN               HU      28.5      -86.6
# 1               NaN               HU      29.6      -86.1
# 2                 L               HU      30.1      -85.7
# 3               NaN               HU      30.7      -85.1
# 4               NaN               HU      31.2      -88.1
#
#    maximum_sustained_wind_knots  ...  34_kt_nw_nm  50_kt_ne_nm  50_kt_se_nm  \
# 0                           100  ...         -999         -999         -999
# 1                           100  ...         -999         -999         -999
# 2                           100  ...         -999         -999         -999
# 3                            90  ...         -999         -999         -999
# 4                            70  ...         -999         -999         -999
#
#    50_kt_sw_nm  50_kt_nw_nm  64_kt_ne_nm  64_kt_se_nm  64_kt_sw_nm  \
# 0         -999         -999         -999         -999         -999
# 1         -999         -999         -999         -999         -999
# 2         -999         -999         -999         -999         -999
# 3         -999         -999         -999         -999         -999
# 4         -999         -999         -999         -999         -999
#
#    64_kt_nw_nm  radius_of_max_wind_nm
# 0         -999                   -999
# 1         -999                   -999
# 2         -999                   -999
# 3         -999                   -999
# 4         -999                   -999
#
# [5 rows x 24 columns]

# %% [markdown]
# Convert the dataframe to csv

# %%
df.to_csv("datasets/hurdat2_formatted.csv", index=False)
print(len(df))
# Out:
# 1945

# %% [markdown]
# **Install Required Libraries**

# %%
# !pip install pymc arviz pandas numpy matplotlib seaborn
# Out:
# Requirement already satisfied: pymc in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (5.22.0)
# Requirement already satisfied: arviz in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (0.21.0)
# Requirement already satisfied: pandas in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: cachetools>=4.2.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (5.5.2)
# Requirement already satisfied: cloudpickle in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (3.1.1)
# Requirement already satisfied: pytensor<2.31,>=2.30.2 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (2.30.2)
# Requirement already satisfied: rich>=13.7.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (14.0.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (1.15.2)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pymc) (4.12.2)
# Requirement already satisfied: setuptools>=60.0.0 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from arviz) (75.8.2)
# Requirement already satisfied: packaging in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from arviz) (24.2)
# Requirement already satisfied: xarray>=2022.6.0 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from arviz) (2025.3.1)
# Requirement already satisfied: h5netcdf>=1.0.2 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from arviz) (1.6.1)
# Requirement already satisfied: xarray-einstats>=0.3 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from arviz) (0.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: h5py in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from h5netcdf>=1.0.2->arviz) (3.13.0)
# Requirement already satisfied: filelock>=3.15 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pytensor<2.31,>=2.30.2->pymc) (3.18.0)
# Requirement already satisfied: etuples in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pytensor<2.31,>=2.30.2->pymc) (0.3.9)
# Requirement already satisfied: logical-unification in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pytensor<2.31,>=2.30.2->pymc) (0.4.6)
# Requirement already satisfied: miniKanren in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pytensor<2.31,>=2.30.2->pymc) (1.0.3)
# Requirement already satisfied: cons in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from pytensor<2.31,>=2.30.2->pymc) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from rich>=13.7.1->pymc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from rich>=13.7.1->pymc) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.2)
# Requirement already satisfied: toolz in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from logical-unification->pytensor<2.31,>=2.30.2->pymc) (1.0.0)
# Requirement already satisfied: multipledispatch in c:\rit\spring 2025\788 capstone\lets_go\.venv\lib\site-packages (from logical-unification->pytensor<2.31,>=2.30.2->pymc) (1.0.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("datasets/resource_dataset_with_id_category_storm_features.csv")  # Replace with your actual file

df['maximum_sustained_wind_knots_max_norm'] = (df['maximum_sustained_wind_knots_max'] - df['maximum_sustained_wind_knots_max'].mean()) / df['maximum_sustained_wind_knots_max'].std()
df['maximum_sustained_wind_knots_mean_norm'] = (df['maximum_sustained_wind_knots_mean'] - df['maximum_sustained_wind_knots_mean'].mean()) / df['maximum_sustained_wind_knots_mean'].std()
df['central_pressure_mb_min_norm'] = (df['central_pressure_mb_min'] - df['central_pressure_mb_min'].mean()) / df['central_pressure_mb_min'].std()
df['central_pressure_mb_mean_norm'] = (df['central_pressure_mb_mean'] - df['central_pressure_mb_mean'].mean()) / df['central_pressure_mb_mean'].std()
df['radius_of_max_wind_nm_max_norm'] = (df['radius_of_max_wind_nm_max'] - df['radius_of_max_wind_nm_max'].mean()) / df['radius_of_max_wind_nm_max'].std()
df['radius_of_max_wind_nm_mean_norm'] = (df['radius_of_max_wind_nm_mean'] - df['radius_of_max_wind_nm_mean'].mean()) / df['radius_of_max_wind_nm_mean'].std()

y = df["shelters"].values
X = df[['maximum_sustained_wind_knots_max_norm', 'maximum_sustained_wind_knots_mean_norm', 'central_pressure_mb_min_norm', 'central_pressure_mb_mean_norm', 'radius_of_max_wind_nm_max_norm', 'radius_of_max_wind_nm_mean_norm']]

# %%
df.head()
# Out:
#   storm_name  category  year  shelters    meals  water_gallons  fuel_gallons  \
# 0    CHARLEY         3  2004       250  2000000         300000        100000
# 1    FRANCES         3  2004       250  3500000        1500000        200000
# 2       IVAN         3  2004       120  2000000         700000        200000
# 3     JEANNE        -1  2004       200  4000000        1500000        200000
# 4     DENNIS        -1  2005        70  1000000         500000        100000
#
#    storm_id  maximum_sustained_wind_knots_max  \
# 0  AL032004                               130
# 1  AL062004                                95
# 2  AL092004                               110
# 3  AL112004                               105
# 4  AL042005                               125
#
#    maximum_sustained_wind_knots_mean  central_pressure_mb_min  \
# 0                         109.444444                    941.0
# 1                          70.000000                    958.0
# 2                          47.272727                    931.0
# 3                          73.333333                    950.0
# 4                         111.250000                    930.0
#
#    central_pressure_mb_mean  radius_of_max_wind_nm_max  \
# 0                957.888889                        5.0
# 1                971.600000                       30.0
# 2                990.545455                       25.0
# 3                965.111111                       45.0
# 4                941.125000                        5.0
#
#    radius_of_max_wind_nm_mean  maximum_sustained_wind_knots_max_norm  \
# 0                         5.0                               0.703856
# 1                        30.0                              -0.938474
# 2                        25.0                              -0.234619
# 3                        45.0                              -0.469237
# 4                         5.0                               0.469237
#
#    maximum_sustained_wind_knots_mean_norm  central_pressure_mb_min_norm  \
# 0                                0.854193                     -0.043873
# 1                               -0.776530                      0.837567
# 2                               -1.716128                     -0.562366
# 3                               -0.638723                      0.422772
# 4                                0.928838                     -0.614216
#
#    central_pressure_mb_mean_norm  radius_of_max_wind_nm_max_norm  \
# 0                      -0.199724                       -1.248173
# 1                       0.549806                        0.780108
# 2                       1.585477                        0.374452
# 3                       0.195085                        1.997077
# 4                      -1.116138                       -1.248173
#
#    radius_of_max_wind_nm_mean_norm
# 0                        -1.207079
# 1                         1.001510
# 2                         0.559792
# 3                         2.326664
# 4                        -1.207079

# %%
import pymc as pm
pm.set_backend("numpy")

with pm.Model() as model:
    intercept = pm.Normal("intercept", mu=0, sigma=10)
    beta_maximum_sustained_wind_knots_max = pm.Normal('beta_maximum_sustained_wind_knots_max', mu=0, sigma=2)
    beta_maximum_sustained_wind_knots_mean = pm.Normal('beta_maximum_sustained_wind_knots_mean', mu=0, sigma=2)
    beta_central_pressure_mb_min = pm.Normal('beta_central_pressure_mb_min', mu=0, sigma=2)
    beta_central_pressure_mb_mean = pm.Normal('beta_central_pressure_mb_mean', mu=0, sigma=2)
    beta_radius_of_max_wind_nm_max = pm.Normal('beta_radius_of_max_wind_nm_max', mu=0, sigma=2)
    beta_radius_of_max_wind_nm_mean = pm.Normal('beta_radius_of_max_wind_nm_mean', mu=0, sigma=2)

    # Prior for standard deviation (must use sigma if using mu)
    sigma = pm.HalfNormal("sigma", sigma=10)

    # Linear model for log(mu) to ensure positivity
    mu = pm.math.exp(
        intercept +
        beta_maximum_sustained_wind_knots_max * X['maximum_sustained_wind_knots_max_norm'].values +
        beta_maximum_sustained_wind_knots_mean * X['maximum_sustained_wind_knots_mean_norm'].values +
        beta_central_pressure_mb_min * X['central_pressure_mb_min_norm'].values +
        beta_central_pressure_mb_mean * X['central_pressure_mb_mean_norm'].values +
        beta_radius_of_max_wind_nm_max * X['radius_of_max_wind_nm_max_norm'].values +
        beta_radius_of_max_wind_nm_mean * X['radius_of_max_wind_nm_mean_norm'].values
    )

    # Gamma likelihood
    y_obs = pm.Gamma("y_obs", mu=mu, sigma=sigma, observed=y)

    # Sample from posterior
    trace = pm.sample(3000, tune=1000, target_accept=0.95, return_inferencedata=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 2
#       1 import pymc as pm
# ----> 2 pm.set_backend("numpy")
#       4 with pm.Model() as model:
#       5     intercept = pm.Normal("intercept", mu=0, sigma=10)
#
# AttributeError: module 'pymc' has no attribute 'set_backend'

# %% [markdown]
# **Define Bayesian Gamma Regression Model**

# %%
import pymc as pm

with pm.Model() as model:
    intercept = pm.Normal("intercept", mu=0, sigma=10)
    beta_wind = pm.Normal("beta_wind", mu=0, sigma=2)
    beta_pressure = pm.Normal("beta_pressure", mu=0, sigma=2)
    beta_radius = pm.Normal("beta_radius", mu=0, sigma=2)
    alpha = pm.HalfNormal("alpha", sigma=10)

    mu = pm.math.exp(
        intercept +
        beta_wind * X["wind_speed_norm"].values +
        beta_pressure * X["pressure_norm"].values +
        beta_radius * X["radius_norm"].values
    )

    y_obs = pm.Gamma("y_obs", mu=mu, alpha=alpha, observed=y)

    trace = pm.sample(3000, tune=1000, target_accept=0.95, return_inferencedata=True)

# %% [markdown]
# **Summarize Posterior Estimates**

# %%
df_pred = pd.read_csv("800_hurricanes.csv")  # Replace with actual file path

df_pred['maximum_sustained_wind_knots_max_norm'] = (df_pred['maximum_sustained_wind_knots_max'] - df_pred['maximum_sustained_wind_knots_max'].mean()) / df_pred['maximum_sustained_wind_knots_max'].std()
df_pred['maximum_sustained_wind_knots_mean_norm'] = (df_pred['maximum_sustained_wind_knots_mean'] - df_pred['maximum_sustained_wind_knots_mean'].mean()) / df_pred['maximum_sustained_wind_knots_mean'].std()
df_pred['central_pressure_mb_min_norm'] = (df_pred['central_pressure_mb_min'] - df_pred['central_pressure_mb_min'].mean()) / df_pred['central_pressure_mb_min'].std()
df_pred['central_pressure_mb_mean_norm'] = (df_pred['central_pressure_mb_mean'] - df_pred['central_pressure_mb_mean'].mean()) / df_pred['central_pressure_mb_mean'].std()
df_pred['radius_of_max_wind_nm_max_norm'] = (df_pred['radius_of_max_wind_nm_max'] - df_pred['radius_of_max_wind_nm_max'].mean()) / df_pred['radius_of_max_wind_nm_max'].std()
df_pred['radius_of_max_wind_nm_mean_norm'] = (df_pred['radius_of_max_wind_nm_mean'] - df_pred['radius_of_max_wind_nm_mean'].mean()) / df_pred['radius_of_max_wind_nm_mean'].std()

with model:
    pm.set_data({
        'maximum_sustained_wind_knots_max_norm': df_pred['maximum_sustained_wind_knots_max_norm'].values,
        'maximum_sustained_wind_knots_mean_norm': df_pred['maximum_sustained_wind_knots_mean_norm'].values,
        'central_pressure_mb_min_norm': df_pred['central_pressure_mb_min_norm'].values,
        'central_pressure_mb_mean_norm': df_pred['central_pressure_mb_mean_norm'].values,
        'radius_of_max_wind_nm_max_norm': df_pred['radius_of_max_wind_nm_max_norm'].values,
        'radius_of_max_wind_nm_mean_norm': df_pred['radius_of_max_wind_nm_mean_norm'].values
    })

    posterior_predictive = pm.sample_posterior_predictive(trace, var_names=["y_obs"])

# %% [markdown]
# **Trace Plots**

# %%
import matplotlib.pyplot as plt

az.plot_trace(trace, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Posterior Predictive Sampling for New Hurricanes**

# %%
df_pred = pd.read_csv("800_hurricanes.csv")  # Replace with actual file path

# Normalize using the same statistics from the training set
for col in features:
    df_pred[f"{col}_norm"] = (df_pred[col] - df[col].mean()) / df[col].std()

with model:
    pm.set_data({
        "wind_speed_norm": df_pred["wind_speed_norm"].values,
        "pressure_norm": df_pred["pressure_norm"].values,
        "radius_norm": df_pred["radius_norm"].values
    })

    posterior_predictive = pm.sample_posterior_predictive(trace, var_names=["y_obs"])

# %% [markdown]
# **Analyze and Save Predictive Output**

# %%
pred_means = posterior_predictive["y_obs"].mean(axis=0)
hdi = az.hdi(posterior_predictive["y_obs"], hdi_prob=0.94)

df_pred["shelters_pred_mean"] = pred_means
df_pred["shelters_95_low"] = hdi[:, 0]
df_pred["shelters_95_high"] = hdi[:, 1]

df_pred.to_csv("synthetic_shelters_predictions.csv", index=False)
